# %% [markdown]
# #Variáveis
#
#  - variáveis são lugares de memória que irão armazenar um dado
#  - <nome da variável> = <dado ou expressão>
#  - seu nome pode ter letra maiúscula, minúscula e o sublinhado
#  - não se deve começar com um número
#  - **Sempre dar um nome significativo, por exemplo item é melhor que apenas i**
#  - para nomes com mais de palavra separe-as com o sublinhado ou use maiúsculas e minúsculas, exemplo (minha Temp, corFlor)
#  - evite nome muito longo

# %%
x=7

# %%
x
# Out:
# 7

# %%
x+3
# Out:
# 10

# %%
var_temp = 38

# %%
varTemp = 38

# %%
y = x + 8

# %%
y
# Out:
# 15
