# %% [markdown]
# #Esse é o meu primeiro programa em Pyhon no Google Colab

# %%
print("Esse é o meu primeiro programa em Python")
# Out:
# Esse é o meu primeiro programa em Python

# %%
print("Olá Mundo")
# Out:
# Olá Mundo
